# %% [markdown]
# # Suggested Problems: Electroanalytical Methods
#
# ## Problem 25-4 from Skoog's *Instrumental Analysis*
#
# > Why is the reference electrode placed near the working electrode in a three-electrode cell?

# %% [markdown]
# ## Problem 25-10 from Skoog's *Intrumental Analysis*
#
# > Quinone undergoes reversible reduction at a voltammetric working electrode. $E^0 = 0.599 \: V$
#
# ![Reduction of quinone into hydroquinone](https://upload.wikimedia.org/wikipedia/commons/3/3f/QuinoneAcidicReduction.png)
#
# > **(a)** Assume that the diffusion coeeficients for quione and hydroquinone are approximately the same and calculated the approximate half-wave potential (versus SCE) for the reduction of hydroquinone at an RDE from a solution buffered to a pH of 8.0. **(b)** Repeat the colucltion in (a) for a solution buffered to a pH of 5.0.
